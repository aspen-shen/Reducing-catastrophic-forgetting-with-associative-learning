# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from matplotlib import pylab as PP
import itertools

plt.style.use('ggplot') # change to ggplot style.
PP.rc('font', **{'sans-serif':'Arial', 'family':'sans-serif'}) # Uses Arial font for all.

# %%
fly1 = pd.read_csv('./FlyModel_all_result_lr0.01_randseed_1.csv',header=None)
fly2 = pd.read_csv('./FlyModel_all_result_lr0.01_randseed_2.csv',header=None)
fly3 = pd.read_csv('./FlyModel_all_result_lr0.01_randseed_3.csv',header=None)
fly4 = pd.read_csv('./FlyModel_all_result_lr0.01_randseed_5.csv',header=None)
fly5 = pd.read_csv('./FlyModel_all_result_lr0.01_randseed_8.csv',header=None)

# %%
n = fly1.shape[0]
fly_1 = [np.mean(fly1.iloc[i,:i+1]) for i in range(n)]
fly_2 = [np.mean(fly2.iloc[i,:i+1]) for i in range(n)]
fly_3 = [np.mean(fly3.iloc[i,:i+1]) for i in range(n)]
fly_4 = [np.mean(fly4.iloc[i,:i+1]) for i in range(n)]
fly_5 = [np.mean(fly5.iloc[i,:i+1]) for i in range(n)]

# %%
fly = pd.DataFrame(
{
    'rand1':fly_1,
    'rand2':fly_2,
    'rand3':fly_3,
    'rand5':fly_4,
    'rand8':fly_5
})

# %%
fly_mean = fly.T.mean()
fly_std = fly.T.std()

# %%
fly_mean
# Out:
# 0    0.997636
# 1    0.943084
# 2    0.909237
# 3    0.881437
# 4    0.852599
# 5    0.862565
# 6    0.835634
# 7    0.796289
# 8    0.738690
# 9    0.739547
# dtype: float64

# %%
ofly1 = pd.read_csv('./Old_FlyModel_all_result_lr0.01_randseed_1.csv',header=None)
ofly2 = pd.read_csv('./Old_FlyModel_all_result_lr0.01_randseed_2.csv',header=None)
ofly3 = pd.read_csv('./Old_FlyModel_all_result_lr0.01_randseed_3.csv',header=None)
ofly4 = pd.read_csv('./Old_FlyModel_all_result_lr0.01_randseed_5.csv',header=None)
ofly5 = pd.read_csv('./Old_FlyModel_all_result_lr0.01_randseed_8.csv',header=None)

n = ofly1.shape[0]
ofly_1 = [np.mean(ofly1.iloc[i,:i+1]) for i in range(n)]
ofly_2 = [np.mean(ofly2.iloc[i,:i+1]) for i in range(n)]
ofly_3 = [np.mean(ofly3.iloc[i,:i+1]) for i in range(n)]
ofly_4 = [np.mean(ofly4.iloc[i,:i+1]) for i in range(n)]
ofly_5 = [np.mean(ofly5.iloc[i,:i+1]) for i in range(n)]

ofly = pd.DataFrame(
{
    'rand1':ofly_1,
    'rand2':ofly_2,
    'rand3':ofly_3,
    'rand5':ofly_4,
    'rand8':ofly_5
})

ofly_mean = ofly.T.mean()
ofly_std = ofly.T.std()

# %%
gem1 = pd.read_csv('./GEM_all_result_lr0.001_randseed_1.csv',header=None)
gem2 = pd.read_csv('./GEM_all_result_lr0.001_randseed_2.csv',header=None)
gem3 = pd.read_csv('./GEM_all_result_lr0.001_randseed_3.csv',header=None)
gem4 = pd.read_csv('./GEM_all_result_lr0.001_randseed_5.csv',header=None)
gem5 = pd.read_csv('./GEM_all_result_lr0.001_randseed_8.csv',header=None)

n = gem1.shape[0]
gem_1 = [np.mean(gem1.iloc[i,:i+1]) for i in range(n)]
gem_2 = [np.mean(gem2.iloc[i,:i+1]) for i in range(n)]
gem_3 = [np.mean(gem3.iloc[i,:i+1]) for i in range(n)]
gem_4 = [np.mean(gem4.iloc[i,:i+1]) for i in range(n)]
gem_5 = [np.mean(gem5.iloc[i,:i+1]) for i in range(n)]

gem = pd.DataFrame(
{
    'rand1':gem_1,
    'rand2':gem_2,
    'rand3':gem_3,
    'rand5':gem_4,
    'rand8':gem_5
})
gem_mean = gem.T.mean()
gem_std = gem.T.std()

# %%
gem_mean
# Out:
# 0    0.997825
# 1    0.870930
# 2    0.809941
# 3    0.803355
# 4    0.740703
# 5    0.695533
# 6    0.657989
# 7    0.604675
# 8    0.477682
# 9    0.458361
# dtype: float64

# %%
ewc1 = pd.read_csv('./EWC_mnist_all_result_lr0.1_randseed_1.csv',header=None)
ewc2 = pd.read_csv('./EWC_mnist_all_result_lr0.1_randseed_2.csv',header=None)
ewc3 = pd.read_csv('./EWC_mnist_all_result_lr0.1_randseed_3.csv',header=None)
ewc4 = pd.read_csv('./EWC_mnist_all_result_lr0.1_randseed_5.csv',header=None)
ewc5 = pd.read_csv('./EWC_mnist_all_result_lr0.1_randseed_8.csv',header=None)

n = ewc1.shape[0]
ewc_1 = [np.mean(ewc1.iloc[i,:i+1]) for i in range(n)]
ewc_2 = [np.mean(ewc2.iloc[i,:i+1]) for i in range(n)]
ewc_3 = [np.mean(ewc3.iloc[i,:i+1]) for i in range(n)]
ewc_4 = [np.mean(ewc4.iloc[i,:i+1]) for i in range(n)]
ewc_5 = [np.mean(ewc5.iloc[i,:i+1]) for i in range(n)]

ewc = pd.DataFrame(
{
    'rand1':ewc_1,
    'rand2':ewc_2,
    'rand3':ewc_3,
    'rand5':ewc_4,
    'rand8':ewc_5
})
ewc_mean = ewc.T.mean()
ewc_std = ewc.T.std()

# %%
ewc_mean
# Out:
# 0    0.998203
# 1    0.802618
# 2    0.716353
# 3    0.675020
# 4    0.619676
# 5    0.594551
# 6    0.584699
# 7    0.478755
# 8    0.387768
# 9    0.409118
# dtype: float64

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2
#plt.hlines(0.8451,2,20,linestyles='dashed',alpha=0.5);
#plt.plot(x, offline, '--', color='black', alpha=0.7, label='Offline')
#plt.errorbar(x, bir_mean, yerr=bir_std, color='#fca311', label='BI-R', ls='-.', marker='*',lw=2);
plt.errorbar(x, fly_mean, yerr=fly_std, color='#E63946',label='Fly Model',marker='o',lw=2);
plt.errorbar(x, ofly_mean, yerr=ofly_std, color='#E63946',label='Fly Model (old)',marker='o',lw=2,ls='-.');
plt.errorbar(x, gem_mean, yerr=gem_std, color='#70C1B3',label='GEM',marker='s',lw=2);
plt.errorbar(x, ewc_mean, yerr=ewc_std, color='#457B9D',label='EWC',marker='>',lw=2);
#plt.errorbar(x, vanilla_mean, yerr=vanilla_std, color='#1D3557',label='Vanilla',marker='<',lw=2);

plt.xlabel('Number of Trained Classes',size=18,color='black');
plt.ylabel('Accuracy of Trained Classes',size=18,color='black');
plt.xticks((np.arange(2, 21, step=2)), size=14,color='black');
plt.yticks(size=14,color='black');
plt.ylim(0,1.1);
#plt.title('With Sparse Coding', fontsize=24);
plt.legend(loc='best',fontsize=14);
#plt.savefig('../figures/Fig_2A.png',dpi=512);

# %%
#==============Computing Time=======================
fly_time_mnist = pd.read_csv('./Fly_MNIST_time_estimate.csv',header=None)
fly_time_cifar = pd.read_csv('./Fly_cifar_time_estimate.csv',header=None)
ofly_time_mnist = pd.read_csv('./Fly_MNIST_time_estimate_old.csv',header=None)
ofly_time_cifar = pd.read_csv('./Fly_cifar_time_estimate_old.csv',header=None)
ewc_time_mnist = pd.read_csv('./EWC_MNIST_time_estimate.csv',header=None)
ewc_time_cifar = pd.read_csv('./EWC_cifar100_time_estimate.csv',header=None)
gem_time_mnist = pd.read_csv('./GEM_MNIST_time_estimate.csv',header=None)
gem_time_cifar = pd.read_csv('./GEM_cifar100_time_estimate.csv',header=None)

# %%
#==============Memory Cost=======================
fly_memory_mnist = pd.read_csv('./Fly_MNIST_memory_estimate.csv',header=None)
fly_memory_cifar = pd.read_csv('./Fly_cifar_memory_estimate.csv',header=None)
ofly_memory_mnist = pd.read_csv('./Fly_MNIST_memory_estimate_old.csv',header=None)
ofly_memory_cifar = pd.read_csv('./Fly_cifar_memory_estimate_old.csv',header=None)
ewc_memory_mnist = pd.read_csv('./EWC_MNIST_memory_estimate.csv',header=None)
ewc_memory_cifar = pd.read_csv('./EWC_cifar100_memory_estimate.csv',header=None)
gem_memory_mnist = pd.read_csv('./GEM_MNIST_memory_estimate.csv',header=None)
gem_memory_cifar = pd.read_csv('./GEM_cifar100_memory_estimate.csv',header=None)

# %%
ofly_memory_mnist
# Out:
#             0
# 0  313.582031
# 1 -129.390625
# 2   -0.003906
# 3    0.003906
# 4   -0.003906

# %%
ewc_memory_mnist
# Out:
#             0
# 0  346.472656
# 1  -58.621094
# 2   22.816406
# 3  -22.632812
# 4   23.054688

# %%
time_estimate = pd.DataFrame()
#time_estimate['FlyModel'] = fly_time_mnist.iloc[:,0]
time_estimate['FlyModel'] = ofly_time_mnist.iloc[:,0]
time_estimate['EWC'] = ewc_time_mnist.iloc[:,0]
time_estimate['GEM'] = gem_time_mnist.iloc[:,0]

# %%
plt.figure(figsize=(10, 5))
#ax = plt.subplot(1, 1, 1)
#ax = time_estimate.mean().plot.bar(color='black');
ax = time_estimate.mean().plot(kind='bar',yerr=time_estimate.std(),color='black')
ax.set_yscale('log')
#time_estimate.plot(kind='box',logy=True);
#ax = sns.barplot(time_estimate.mean());
plt.ylabel('Estimated Running Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.title('MNIST-20',fontsize=32);
plt.ylim(1,3000)
# Out:
# (1, 3000)

# %%
time_estimate.std()
# Out:
# FlyModel     0.917492
# EWC          0.962523
# GEM         18.678603
# dtype: float64

# %%
time_estimate.mean()
# Out:
# FlyModel     109.338033
# EWC           14.391287
# GEM         1095.997993
# dtype: float64

# %%
time_estimate = pd.DataFrame()
time_estimate['FlyModel'] = fly_time_mnist.iloc[:,0]
time_estimate['Original FlyModel'] = ofly_time_mnist.iloc[:,0]
time_estimate['EWC'] = ewc_time_mnist.iloc[:,0]

# %%
plt.figure(figsize=(10,5))
time_estimate.boxplot();
plt.ylabel('Estimated Running Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.title('MNIST-20',fontsize=32);

# %%
fly_memory_mnist.iloc[1:,0] += fly_memory_mnist.iloc[0,0]
fly_memory_cifar.iloc[1:,0] += fly_memory_cifar.iloc[0,0]
ofly_memory_cifar.iloc[1:,0] += ofly_memory_cifar.iloc[0,0]
ofly_memory_mnist.iloc[1:,0] += ofly_memory_mnist.iloc[0,0]
ewc_memory_cifar.iloc[1:,0] += ewc_memory_cifar.iloc[0,0]
ewc_memory_mnist.iloc[1:,0] += ewc_memory_mnist.iloc[0,0]
gem_memory_cifar.iloc[1:,0] += gem_memory_cifar.iloc[0,0]
gem_memory_mnist.iloc[1:,0] += gem_memory_mnist.iloc[0,0]

# %%
memory_estimate = pd.DataFrame()
#memory_estimate['FlyModel'] = fly_memory_mnist.iloc[:,0]
memory_estimate['FlyModel'] = ofly_memory_mnist.iloc[:,0]
memory_estimate['EWC'] = ewc_memory_mnist.iloc[:,0]
memory_estimate['GEM'] = gem_memory_mnist.iloc[:,0]

# %%
mnist_memory = pd.DataFrame()
mnist_memory['Memory'] = np.concatenate([ofly_memory_mnist.iloc[:,0],ewc_memory_mnist.iloc[:,0],
                                    gem_memory_mnist.iloc[:,0]])
mnist_memory['Algorithms'] = np.repeat(np.array(['FlyModel','EWC','GEM']),5)

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=mnist_memory,x='Algorithms',y='Memory',capsize=0.1,linewidth=3, edgecolor=".5", facecolor=(0, 0, 0, 0));
#plt.yscale('log');
plt.ylabel('Estimated Memory Usage (MB)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.xlabel('');
#plt.ylim(1,2000);
#plt.title('MNIST-20',fontsize=32);
plt.tight_layout();
plt.savefig('./mnist_memory.png',dpi=512);

# %%
plt.figure(figsize=(10,5))
memory_estimate.boxplot();
#ax.set_yscale('log');
plt.ylabel('Estimated Memory Usage (Mb)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
#plt.title('MNIST-20',fontsize=32);

# %%
plt.figure(figsize=(7, 5))
#ax = plt.subplot(1, 1, 1)
#ax = time_estimate.mean().plot.bar(color='black');
ax = memory_estimate.mean().plot(kind='bar',yerr=memory_estimate.std(),color='black')
#ax.set_yscale('log')
#time_estimate.plot(kind='box',logy=True);
#ax = sns.barplot(time_estimate.mean());
plt.ylabel('Estimated Memory Usage (Mb)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
#plt.title('MNIST-20',fontsize=32);
plt.ylim(1,850);

# %% [markdown]
# # CIFAR-100

# %%
time_estimate = pd.DataFrame()
#time_estimate['FlyModel'] = fly_time_cifar.iloc[:,0]
time_estimate['FlyModel'] = ofly_time_cifar.iloc[:,0]
time_estimate['EWC'] = ewc_time_cifar.iloc[:,0]
time_estimate['GEM'] = gem_time_cifar.iloc[:,0]

# %%
plt.figure(figsize=(10,5))
ax = time_estimate.boxplot();
ax.set_yscale('log')
plt.ylabel('Estimated Running Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.title('CIFAR-100',fontsize=32);

# %%
time_estimate = pd.DataFrame()
#time_estimate['FlyModel'] = fly_time_cifar.iloc[:,0]
time_estimate['FlyModel'] = ofly_time_cifar.iloc[:,0]
time_estimate['EWC'] = ewc_time_cifar.iloc[:,0]
time_estimate['GEM'] = gem_time_cifar.iloc[:,0]

# %%
plt.figure(figsize=(10,5))
time_estimate.boxplot();
plt.ylabel('Estimated Running Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.title('CIFAR-100',fontsize=32);

# %%
plt.figure(figsize=(7, 5))
#ax = plt.subplot(1, 1, 1)
#ax = time_estimate.mean().plot.bar(color='black');
ax = time_estimate.mean().plot(kind='bar',yerr=time_estimate.std(),color='black')
ax.set_yscale('log')
#time_estimate.plot(kind='box',logy=True);
#ax = sns.barplot(time_estimate.mean());
plt.ylabel('Estimated Running Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
#plt.title('CIFAR-100',fontsize=32);
plt.ylim(1,70000)
# Out:
# (1, 70000)

# %%
memory_estimate = pd.DataFrame()
#memory_estimate['FlyModel'] = fly_memory_cifar.iloc[:,0]
memory_estimate['FlyModel'] = ofly_memory_cifar.iloc[:,0]
memory_estimate['EWC'] = ewc_memory_cifar.iloc[:,0]
memory_estimate['GEM'] = gem_memory_cifar.iloc[:,0]

# %%
cifar_memory = pd.DataFrame()
cifar_memory['Memory'] = np.concatenate([ofly_memory_cifar.iloc[:,0],ewc_memory_cifar.iloc[:,0],
                                    gem_memory_cifar.iloc[:,0]])
cifar_memory['Algorithms'] = np.repeat(np.array(['FlyModel','EWC','GEM']),5)

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=cifar_memory,x='Algorithms',y='Memory',capsize=0.1,linewidth=3, edgecolor=".5", facecolor=(0, 0, 0, 0));
plt.yscale('log');
plt.ylabel('Estimated Memory Usage (MB)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.xlabel('');
plt.ylim(1,10**5);
#plt.title('CIFAR-100',fontsize=32);
plt.tight_layout();
plt.savefig('./cifar_memory.png',dpi=512);

# %%
plt.figure(figsize=(10,5))
ax = memory_estimate.boxplot();
ax.set_yscale('log');
plt.ylabel('Estimated Memory Usage (Mb)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
#plt.title('CIFAR-100',fontsize=32);

# %%
plt.figure(figsize=(7, 5))
#ax = plt.subplot(1, 1, 1)
#ax = time_estimate.mean().plot.bar(color='black');
ax = memory_estimate.mean().plot(kind='bar',yerr=memory_estimate.std(),color='black')
ax.set_yscale('log')
#time_estimate.plot(kind='box',logy=True);
#ax = sns.barplot(time_estimate.mean());
plt.ylabel('Estimated Memory Usage (Mb)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
#plt.title('CIFAR-100',fontsize=32);
plt.ylim(1,10**5);

# %%
memory_estimate = pd.DataFrame()
memory_estimate['FlyModel'] = fly_memory_cifar.iloc[:,0]
memory_estimate['Original FlyModel'] = ofly_memory_cifar.iloc[:,0]
memory_estimate['EWC'] = ewc_memory_cifar.iloc[:,0]

# %%
plt.figure(figsize=(10,5))
memory_estimate.boxplot();
plt.ylabel('Estimated Memory Usage (Mb)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.title('CIFAR-100',fontsize=32);

# %%
memory_estimate
# Out:
#      FlyModel  Original FlyModel          EWC
# 0  294.085938         252.250000  3822.804688
# 1  323.714844         281.789062  3723.304688
# 2  294.101562         252.246094  3769.039062
# 3  294.109375         252.250000  3822.855469
# 4  294.101562         252.257812  3693.015625

# %%
ewc_time_per_task = pd.read_csv('./EWC_mnist_time_per_tast.csv',header=None)
fly_time_per_task = pd.read_csv('./Fly_MNIST_time_per_tast.csv',header=None)
gem_time_per_task = pd.read_csv('./GEM_MNIST_time_per_task.csv',header=None)

# %%
ewc_mean_time = np.mean(ewc_time_per_task.iloc[1:,:],axis=0)
ewc_std_time = np.std(ewc_time_per_task.iloc[1:,:],axis=0)
fly_mean_time = np.mean(fly_time_per_task.iloc[1:,:],axis=0)
fly_std_time = np.std(fly_time_per_task.iloc[1:,:],axis=0)

# %%
plt.figure(figsize=(7,5))
plt.errorbar(range(1,11),ewc_mean_time,yerr=ewc_std_time,label='EWC',color='#457B9D');
plt.errorbar(range(1,11),fly_mean_time,yerr=fly_std_time,label='FlyModel',color='#E63946');
plt.xlabel('Task ID',fontsize=28);
plt.ylabel('Training Time per Task(s)',fontsize=28);
plt.xticks(fontsize=24);
plt.yticks(fontsize=24);
#plt.legend(loc='best',fontsize=16);
plt.title('MNIST-20',fontsize=32);
plt.tight_layout();
plt.savefig('./mnist_single_time.png',dpi=512);

# %%
fly_time_per_task
# Out:
#           0         1         2         3         4         5         6  \
# 0  6.911181  6.403477  5.861053  6.278994  6.171116  6.339067  6.331741
# 1  6.693180  4.937955  4.410905  4.815780  4.599756  4.736061  4.761865
# 2  4.938163  4.665305  4.391174  4.697580  4.587297  4.693052  4.688637
# 3  6.398302  6.239739  5.863648  6.219562  6.123987  6.176917  6.256589
# 4  7.294772  6.956606  6.477309  7.041328  6.824033  6.944077  6.935161
# 5  6.549966  6.377288  5.862780  6.617121  6.815594  6.930412  6.973614
#
#           7         8         9
# 0  6.212999  6.224308  6.275950
# 1  4.769370  4.746985  4.743574
# 2  4.655143  4.667414  6.284926
# 3  6.867665  6.855902  6.782154
# 4  6.787760  6.846933  6.235696
# 5  6.374733  6.286950  6.285133

# %%
ewc_time_per_task
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.170426  0.615075  0.715038  0.965502  1.066261  1.216624  1.416677
# 1  0.464684  0.564705  0.665126  0.865546  0.965712  1.165829  1.316598
# 2  0.414494  0.564757  0.665204  0.865547  1.015836  1.166331  1.316309
# 3  0.414622  0.565049  0.614819  0.865174  1.015838  1.166015  1.316310
# 4  0.414772  0.514596  0.614513  0.865419  0.965548  1.165820  1.316339
# 5  0.414861  0.514665  0.614923  0.815363  0.965809  1.165880  1.316126
#
#           7         8         9
# 0  1.566881  1.717179  1.917464
# 1  1.516717  1.666504  1.817163
# 2  1.516840  1.666953  1.817073
# 3  1.516568  1.667005  1.867240
# 4  1.516536  1.666856  1.817129
# 5  1.466583  1.666827  1.816971

# %%
f, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, sharex=True, gridspec_kw={'height_ratios':[1, 3]}, figsize=(7,5))
# Plot the data on both axes.
ax1.errorbar(range(1,11),fly_mean_time,yerr=fly_std_time,label='FlyModel',color='#E63946');
ax2.errorbar(range(1,11),ewc_mean_time,yerr=ewc_std_time,label='EWC',color='#457B9D');

plt.xlabel("Task ID",fontsize=28);
plt.locator_params(nbins=4,axis='y');
ax1.set_title('MNIST-20',fontsize=32);
plt.yticks(fontsize=24);
ax2.set_ylabel("Estimated Time (s)",size=28);
ax2.set_xticklabels(['0','2','4','6','8','10'],size=24);
ax2.set_ylim(0,3)
ax1.set_yticklabels(labels=[4,6],size=24);

ax1.set_ylabel("")
ax1.set_ylim(4,7.5);
# Out:
# C:\Users\Serene\AppData\Local\Temp\ipykernel_1600\2853841539.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(['0','2','4','6','8','10'],size=24);
# C:\Users\Serene\AppData\Local\Temp\ipykernel_1600\2853841539.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(labels=[4,6],size=24);

# %%
ewc_time_per_task_cifar = pd.read_csv('./EWC_cifar100_time_per_task.csv',header=None)
fly_time_per_task_cifar = pd.read_csv('./Fly_cifar_time_per_tast.csv',header=None)
gem_time_per_task_cifar = pd.read_csv('./GEM_cifar100_time_per_task.csv',header=None)

# %%
ewc_mean_time_cifar = np.mean(ewc_time_per_task_cifar.iloc[1:,:],axis=0)
ewc_std_time_cifar = np.std(ewc_time_per_task_cifar.iloc[1:,:],axis=0)
fly_mean_time_cifar = np.mean(fly_time_per_task_cifar.iloc[1:,:],axis=0)
fly_std_time_cifar = np.std(fly_time_per_task_cifar.iloc[1:,:],axis=0)
gem_mean_time_cifar = np.mean(gem_time_per_task_cifar.iloc[1:,:],axis=0)
gem_std_time_cifar = np.std(gem_time_per_task_cifar.iloc[1:,:],axis=0)

# %%
plt.figure(figsize=(7,5))
plt.errorbar(range(1,26),ewc_mean_time_cifar,yerr=ewc_std_time_cifar,label='EWC',color='#457B9D');
plt.errorbar(range(1,26),fly_mean_time_cifar,yerr=fly_std_time_cifar,label='FlyModel',color='#E63946');
plt.xlabel('Task ID',fontsize=28);
plt.ylabel('Training Time per Task (s)',fontsize=28);
plt.locator_params(nbins=6,axis='y');
plt.xticks(fontsize=24);
plt.yticks(fontsize=24);
plt.legend(loc='best',fontsize=20);
plt.title('CIFAR-100',fontsize=32);
plt.tight_layout();
plt.savefig('./cifar_single_time.tiff',dpi=512);

# %%
ewc_mean_time_cifar
# Out:
# 0      0.304734
# 1      0.716251
# 2      1.107802
# 3      1.468964
# 4      1.860411
# 5      2.181665
# 6      2.552635
# 7      3.034596
# 8      3.445832
# 9      3.827026
# 10     4.528516
# 11     5.199498
# 12     5.791095
# 13     6.432608
# 14     6.964094
# 15     7.585009
# 16     8.136624
# 17     8.719088
# 18     9.350129
# 19    10.000549
# 20    10.635766
# 21    11.197419
# 22    11.809187
# 23    12.511014
# 24    13.032638
# dtype: float64

# %%
ewc_time_per_task_cifar.T.sum()
# Out:
# 0    172.009776
# 1    160.193828
# 2    151.308695
# 3    148.995446
# 4    149.621570
# 5    151.846206
# dtype: float64

# %%
fly_time_per_task_cifar.T.sum()
# Out:
# 0    60.083743
# 1    58.699067
# 2    59.357128
# 3    56.333399
# 4    59.733646
# dtype: float64

# %%
gem_time_per_task_cifar.T.sum()
# Out:
# 0    43151.378837
# 1    43511.537822
# 2    43065.044122
# 3    42612.902116
# 4    43183.861872
# dtype: float64

# %%
fly_time_per_task.T.sum().values
# Out:
# array([63.00988698, 49.2154305 , 48.26869154, 63.78446484, 68.34367394,
#        65.07358932])

# %%
ewc_time_per_task.T.sum()
# Out:
# 0    13.367128
# 1    11.008584
# 2    11.009343
# 3    11.008640
# 4    10.857528
# 5    10.758007
# dtype: float64

# %%
mnist_time = pd.DataFrame()
mnist_time['Time'] = np.concatenate([fly_time_per_task.T.sum().values[1:],ewc_time_per_task.T.sum().values[1:],
                                    gem_time_per_task.T.sum().values])
mnist_time['Algorithms'] = np.repeat(np.array(['FlyModel','EWC','GEM']),5)

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=mnist_time,x='Algorithms',y='Time',capsize=0.1,linewidth=3, edgecolor=".5", facecolor=(0, 0, 0, 0));
plt.yscale('log');
plt.ylabel('Training Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.xlabel('');
plt.ylim(1,2000);
plt.title('MNIST-20',fontsize=32);
plt.tight_layout();
plt.savefig('./mnist_total_time.png',dpi=512);

# %%
cifar_time = pd.DataFrame()
cifar_time['Time'] = np.concatenate([fly_time_per_task_cifar.T.sum().values,ewc_time_per_task_cifar.T.sum().values[1:],
                                    gem_time_per_task_cifar.T.sum().values])
cifar_time['Algorithms'] = np.repeat(np.array(['FlyModel','EWC','GEM']),5)

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=cifar_time,x='Algorithms',y='Time',capsize=0.1,linewidth=3, edgecolor=".5", facecolor=(0, 0, 0, 0));
plt.yscale('log');
plt.ylabel('Training Time (s)',fontsize=24);
plt.yticks(fontsize=20);
plt.xticks(fontsize=20);
plt.xlabel('');
plt.ylim(1,60000);
plt.title('CIFAR-100',fontsize=32);
plt.tight_layout();
plt.savefig('./cifar_total_time.png',dpi=512);
